# %%
import pandas

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'jupyterApp.ipynb',
#  'learnPandas.ipynb',
#  'scrape.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testings.ipynb',
#  'Untitled.ipynb']

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+","+df["Country"]
df
# Out:
#    ID                                           Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114,USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119,USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114,USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California,USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114,USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df=df.set_index("ID")
df
# Out:
#                                              Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114,USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119,USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114,USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114,USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California,USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114,USA  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df
# Out:
#                                              Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114,USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119,USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114,USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114,USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California,USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114,USA  San Francisco
#
#                State Country         Name  Employees  \
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20
#
#                                           Coordinates   Latitude   Longitude
# ID
# 1   (3666 21st St, San Francisco, California, 9411...  37.756444 -122.429353
# 2   (735 Dolores St, San Francisco, California, 94...  37.757801 -122.425599
# 3   (332 Hill St, San Francisco, California, 94114...  37.755641 -122.428794
# 4   (3995 23rd St, San Francisco, California, 9411...  37.752985 -122.431702
# 5   (1056 Sanchez St, San Francisco, California, 9...  37.752144 -122.429758
# 6   (551 Alvarado St, San Francisco, California, 9...  37.753709 -122.433251

# %%
first = df.iloc[0,1]
first
# Out:
# 'San Francisco'

# %%
df_t=df.T

# %%
df_t
# Out:
# ID                                                           1  \
# Address              3666 21st St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                   Madeira
# Employees                                                    8
# Coordinates  (3666 21st St, San Francisco, California, 9411...
# Latitude                                               37.7564
# Longitude                                             -122.429
#
# ID                                                           2  \
# Address            735 Dolores St, San Francisco, CA 94119,USA
# City                                             San Francisco
# State                                                 CA 94119
# Country                                                    USA
# Name                                               Bready Shop
# Employees                                                   15
# Coordinates  (735 Dolores St, San Francisco, California, 94...
# Latitude                                               37.7578
# Longitude                                             -122.426
#
# ID                                                           3  \
# Address       332 Hill St, San Francisco, California 94114,USA
# City                                             San Francisco
# State                                         California 94114
# Country                                                    USA
# Name                                               Super River
# Employees                                                   25
# Coordinates  (332 Hill St, San Francisco, California, 94114...
# Latitude                                               37.7556
# Longitude                                             -122.429
#
# ID                                                           4  \
# Address              3995 23rd St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                Ben's Shop
# Employees                                                   10
# Coordinates  (3995 23rd St, San Francisco, California, 9411...
# Latitude                                                37.753
# Longitude                                             -122.432
#
# ID                                                           5  \
# Address         1056 Sanchez St, San Francisco, California,USA
# City                                             San Francisco
# State                                               California
# Country                                                    USA
# Name                                                   Sanchez
# Employees                                                   12
# Coordinates  (1056 Sanchez St, San Francisco, California, 9...
# Latitude                                               37.7521
# Longitude                                              -122.43
#
# ID                                                           6
# Address           551 Alvarado St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                Richvalley
# Employees                                                   20
# Coordinates  (551 Alvarado St, San Francisco, California, 9...
# Latitude                                               37.7537
# Longitude                                             -122.433

# %%
df_t["7"]=["750 Main St, ","Reisterstown","MD 21136","USA","Andy",6,"x","x","x"]

# %%
df_t
# Out:
# ID                                                           1  \
# Address              3666 21st St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                   Madeira
# Employees                                                    8
# Coordinates  (3666 21st St, San Francisco, California, 9411...
# Latitude                                               37.7564
# Longitude                                             -122.429
#
# ID                                                           2  \
# Address            735 Dolores St, San Francisco, CA 94119,USA
# City                                             San Francisco
# State                                                 CA 94119
# Country                                                    USA
# Name                                               Bready Shop
# Employees                                                   15
# Coordinates  (735 Dolores St, San Francisco, California, 94...
# Latitude                                               37.7578
# Longitude                                             -122.426
#
# ID                                                           3  \
# Address       332 Hill St, San Francisco, California 94114,USA
# City                                             San Francisco
# State                                         California 94114
# Country                                                    USA
# Name                                               Super River
# Employees                                                   25
# Coordinates  (332 Hill St, San Francisco, California, 94114...
# Latitude                                               37.7556
# Longitude                                             -122.429
#
# ID                                                           4  \
# Address              3995 23rd St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                Ben's Shop
# Employees                                                   10
# Coordinates  (3995 23rd St, San Francisco, California, 9411...
# Latitude                                                37.753
# Longitude                                             -122.432
#
# ID                                                           5  \
# Address         1056 Sanchez St, San Francisco, California,USA
# City                                             San Francisco
# State                                               California
# Country                                                    USA
# Name                                                   Sanchez
# Employees                                                   12
# Coordinates  (1056 Sanchez St, San Francisco, California, 9...
# Latitude                                               37.7521
# Longitude                                              -122.43
#
# ID                                                           6              7
# Address           551 Alvarado St, San Francisco, CA 94114,USA  750 Main St,
# City                                             San Francisco   Reisterstown
# State                                                 CA 94114       MD 21136
# Country                                                    USA            USA
# Name                                                Richvalley           Andy
# Employees                                                   20              6
# Coordinates  (551 Alvarado St, San Francisco, California, 9...              x
# Latitude                                               37.7537              x
# Longitude                                             -122.433              x

# %%
df_t["7"]=["750 Main St, "+df_t.iloc[1,6]+", "+df_t.iloc[2,6]+", "+df_t.iloc[3,6],"Reisterstown","MD 21136","USA","Andy",6,"x","x","x"]
df_t
# Out:
# ID                                                           1  \
# Address              3666 21st St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                   Madeira
# Employees                                                    8
# Coordinates  (3666 21st St, San Francisco, California, 9411...
# Latitude                                               37.7564
# Longitude                                             -122.429
#
# ID                                                           2  \
# Address            735 Dolores St, San Francisco, CA 94119,USA
# City                                             San Francisco
# State                                                 CA 94119
# Country                                                    USA
# Name                                               Bready Shop
# Employees                                                   15
# Coordinates  (735 Dolores St, San Francisco, California, 94...
# Latitude                                               37.7578
# Longitude                                             -122.426
#
# ID                                                           3  \
# Address       332 Hill St, San Francisco, California 94114,USA
# City                                             San Francisco
# State                                         California 94114
# Country                                                    USA
# Name                                               Super River
# Employees                                                   25
# Coordinates  (332 Hill St, San Francisco, California, 94114...
# Latitude                                               37.7556
# Longitude                                             -122.429
#
# ID                                                           4  \
# Address              3995 23rd St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                Ben's Shop
# Employees                                                   10
# Coordinates  (3995 23rd St, San Francisco, California, 9411...
# Latitude                                                37.753
# Longitude                                             -122.432
#
# ID                                                           5  \
# Address         1056 Sanchez St, San Francisco, California,USA
# City                                             San Francisco
# State                                               California
# Country                                                    USA
# Name                                                   Sanchez
# Employees                                                   12
# Coordinates  (1056 Sanchez St, San Francisco, California, 9...
# Latitude                                               37.7521
# Longitude                                              -122.43
#
# ID                                                           6  \
# Address           551 Alvarado St, San Francisco, CA 94114,USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                Richvalley
# Employees                                                   20
# Coordinates  (551 Alvarado St, San Francisco, California, 9...
# Latitude                                               37.7537
# Longitude                                             -122.433
#
# ID                                                  7
# Address      750 Main St, Reisterstown, MD 21136, USA
# City                                     Reisterstown
# State                                        MD 21136
# Country                                           USA
# Name                                             Andy
# Employees                                           6
# Coordinates                                         x
# Latitude                                            x
# Longitude                                           x

# %%
df=df_t.T
df
# Out:
#                                              Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114,USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119,USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114,USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114,USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California,USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114,USA  San Francisco
# 7           750 Main St, Reisterstown, MD 21136, USA   Reisterstown
#
#                State Country         Name Employees  \
# ID
# 1           CA 94114     USA      Madeira         8
# 2           CA 94119     USA  Bready Shop        15
# 3   California 94114     USA  Super River        25
# 4           CA 94114     USA   Ben's Shop        10
# 5         California     USA      Sanchez        12
# 6           CA 94114     USA   Richvalley        20
# 7           MD 21136     USA         Andy         6
#
#                                           Coordinates Latitude Longitude
# ID
# 1   (3666 21st St, San Francisco, California, 9411...  37.7564  -122.429
# 2   (735 Dolores St, San Francisco, California, 94...  37.7578  -122.426
# 3   (332 Hill St, San Francisco, California, 94114...  37.7556  -122.429
# 4   (3995 23rd St, San Francisco, California, 9411...   37.753  -122.432
# 5   (1056 Sanchez St, San Francisco, California, 9...  37.7521   -122.43
# 6   (551 Alvarado St, San Francisco, California, 9...  37.7537  -122.433
# 7                                                   x        x         x

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df
# Out:
#                                              Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114,USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119,USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114,USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114,USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California,USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114,USA  San Francisco
# 7           750 Main St, Reisterstown, MD 21136, USA   Reisterstown
#
#                State Country         Name Employees  \
# ID
# 1           CA 94114     USA      Madeira         8
# 2           CA 94119     USA  Bready Shop        15
# 3   California 94114     USA  Super River        25
# 4           CA 94114     USA   Ben's Shop        10
# 5         California     USA      Sanchez        12
# 6           CA 94114     USA   Richvalley        20
# 7           MD 21136     USA         Andy         6
#
#                                           Coordinates   Latitude   Longitude
# ID
# 1   (3666 21st St, San Francisco, California, 9411...  37.756444 -122.429353
# 2   (735 Dolores St, San Francisco, California, 94...  37.757801 -122.425599
# 3   (332 Hill St, San Francisco, California, 94114...  37.755641 -122.428794
# 4   (3995 23rd St, San Francisco, California, 9411...  37.752985 -122.431702
# 5   (1056 Sanchez St, San Francisco, California, 9...  37.752144 -122.429758
# 6   (551 Alvarado St, San Francisco, California, 9...  37.753709 -122.433251
# 7   (750 Main St, Reisterstown, Maryland, 21136, (...  39.451632  -76.819952
